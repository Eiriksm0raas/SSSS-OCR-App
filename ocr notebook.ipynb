# %%
import keras_ocr
from matplotlib import pyplot as plt

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for C:\Users\eirik\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\eirik\.keras-ocr\crnn_kurapan.h5

# %%
images = [
    keras_ocr.tools.read(url) for url in [
        'https://upload.wikimedia.org/wikipedia/commons/b/bd/Army_Reserves_Recruitment_Banner_MOD_45156284.jpg',
        'https://upload.wikimedia.org/wikipedia/commons/6/6c/Mobile_Bicycle_Billboard_from_Singapore%2C_April_9_2013.jpg',
        'https://upload.wikimedia.org/wikipedia/commons/b/b4/EUBanana-500x112.jpg'
    ]
]

# %%
# Each list of predictions in prediction_groups is a list of
# (word, box) tuples.
prediction_groups = pipeline.recognize(images)
# Out:
# 1/1 [==============================] - 20s 20s/step
# 2/2 [==============================] - 2s 291ms/step

# %%
# Plot the predictions
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)

# %%
prediction = prediction_groups[2]

# %%
print(prediction)
# Out:
# [('banana', array([[262.,  20.],
#        [357.,  20.],
#        [357.,  39.],
#        [262.,  39.]], dtype=float32)), ('union', array([[364.,  20.],
#        [440.,  20.],
#        [440.,  40.],
#        [364.,  40.]], dtype=float32)), ('no', array([[223.,  21.],
#        [257.,  21.],
#        [257.,  40.],
#        [223.,  40.]], dtype=float32)), ('no', array([[209.,  75.],
#        [235.,  75.],
#        [235.,  94.],
#        [209.,  94.]], dtype=float32)), ('software', array([[248.,  75.],
#        [352.,  75.],
#        [352.,  94.],
#        [248.,  94.]], dtype=float32)), ('patents', array([[365.99997,  74.99999],
#        [456.99997,  74.99999],
#        [456.99997,  93.99999],
#        [365.99997,  93.99999]], dtype=float32))]

# %%
print(type(prediction[0][1]))
# Out:
# <class 'numpy.ndarray'>
